# %% [markdown]
# # Test PDF Error Handling
#
# This notebook tests the improved error handling for PDF uploads with OpenAI.

# %%
# Check current model
# %llm_model

# %%
# First test without PDF
# %%llm
Hello! Can you confirm you're working?

# %%
# Upload a test PDF
# Note: Replace with your own PDF path
# %llm_pdf_native /path/to/test.pdf

# %%
# Test query with PDF
# %%llm
Can you summarize the main points of the uploaded document?

# %% [markdown]
# ## Expected Results
#
# If OpenAI returns an InternalServerError, you should now see a helpful error message like:
#
# ```
# Error: litellm.InternalServerError: OpenAIException - The server had an error...
#
# 💡 This is a temporary OpenAI server issue. Suggestions:
#   • Wait a few moments and try again
#   • If using a PDF, ensure it's under 20MB
#   • Try with a smaller or different PDF
#   • Check OpenAI status: https://status.openai.com
# ```

# %%
# Test with a smaller query to see if it's PDF-specific
# %%llm
What is 2 + 2? (Testing without PDF reference)

# %%
# Clear uploaded files if needed
# %llm_files_clear
